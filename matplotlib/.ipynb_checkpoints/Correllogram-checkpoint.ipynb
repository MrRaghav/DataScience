# %% [markdown]
# # Correllogram

# %% [markdown]
# reference->
#
# https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/#8.-Correllogram

# %%
# Import libraries
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline  #to show the figure
# Out:
# UsageError: unrecognized arguments: #to show the figure

# %%
#Import the dataset
df = pd.read_csv("https://github.com/selva86/datasets/raw/master/mtcars.csv")

# %%
# Plot the correllogram
plt.figure(figsize=(13,11), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of mtcars', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
