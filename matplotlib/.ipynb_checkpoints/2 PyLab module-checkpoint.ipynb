# %% [markdown]
# reference:
#
# https://www.tutorialspoint.com/matplotlib/matplotlib_pylab_module.htm

# %%
from numpy import *
from pylab import *

# %%
x = linspace(-3, 3, 30)
y = x**2
plot(x, y)
show()

# %%
x = linspace(-3, 3, 30)
y = x**2
plot(x, y, 'r.')
show()

# %%
plot(x, sin(x))
plot(x, cos(x), 'r-')
plot(x, -sin(x), 'g--')
show()
