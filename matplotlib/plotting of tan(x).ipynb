# %% [markdown]
# references->
#
# https://pythonforundergradengineers.com/plotting-sin-cos-with-matplotlib.html
#
# https://pythontic.com/visualization/charts/sinewave

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig, ax = plt.subplots(figsize=(10,7))

# arange for the x value with .1 as steps
x1 = np.arange(-7.5, +7.5 , .1)    #start , stop and steps

# arange for the x value with .5 as steps
x2 = np.arange(-7.5, +7.5 , .5)    #start , stop and steps

# arange for the x value with 1 as steps
x3 = np.arange(-7.5, +7.5 , 1)    #start , stop and steps

y1 = np.tan(x1)
y2 = np.tan(x2)
y3 = np.tan(x3)
# Plot the data
plt.plot(x1,y1) #smoothest with .1 step
plt.plot(x2,y2) #sharper with .5 step
plt.plot(x3,y3) #sharpest with 1 step

plt.title('example of cos function')

# Show the plot
plt.show()

# %% [markdown]
# another way:
#
# https://stackoverflow.com/questions/54505852/how-to-plot-tanx-with-pyplot-and-numpy

# %%
import matplotlib.pyplot as plt
import numpy as np
argumentForTan = np.linspace(-5.0, 10) #default of linspace is 50 -> https://numpy.org/doc/1.18/reference/generated/numpy.linspace.html
plt.plot(argumentForTan, np.tan(x))
plt.ylim(-5, 5)
plt.show()
