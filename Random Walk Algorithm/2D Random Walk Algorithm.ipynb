# %% [markdown]
# "After guidance from GeeksforGeeks: https://www.geeksforgeeks.org/random-walk-implementation-python/ "
# #Not for Commercial Use
# #Self_Practice

# %%
# Python code for 2D random walk. 
import numpy 
import pylab 
import random 
# %matplotlib inline
# defining the number of steps 
# for 1000 steps
n = 15
  
#creating two array for containing x and y coordinate 
#of size equals to the number of size and filled up with 0's 
x = numpy.zeros(n) 
y = numpy.zeros(n) 
  
# filling the coordinates with random variables 
for i in range(1, n): 
    val = random.randint(1, 3) 
    if val == 1: 
        x[i] = x[i - 1] + 1
        y[i] = y[i - 1] 
    elif val == 2: 
        x[i] = x[i - 1] - 1
        y[i] = y[i - 1] 
    else: 
    #elif val == 3: 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] + 1
    #else: 
    #    x[i] = x[i - 1] 
    #   y[i] = y[i - 1] - 1
      
  
# plotting the graph: 
pylab.title("Walking Ramdomly ($n = " + str(n) + "$ steps)") 
pylab.plot(x, y, x , y) 
#pylab.plot(x, y) 
#pylab.savefig("rand_walk"+str(n)+".png",bbox_inches="tight",dpi=600) 
pylab.show()

# %%
# Python code for 2D random walk. 
import numpy 
import pylab 
import random 
# %matplotlib inline
# defining the number of steps 
# for 10000 steps
n = 10000
  
#creating two array for containing x and y coordinate 
#of size equals to the number of size and filled up with 0's 
x = numpy.zeros(n) 
y = numpy.zeros(n) 
  
# filling the coordinates with random variables 
for i in range(1, n): 
    val = random.randint(1, 4) 
    if val == 1: 
        x[i] = x[i - 1] + 1
        y[i] = y[i - 1] 
    elif val == 2: 
        x[i] = x[i - 1] - 1
        y[i] = y[i - 1] 
    elif val == 3: 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] + 1
    #elif val == 4: 
    #    x[i] = x[i - 1] 
    #    y[i] = y[i - 1] - 1
    else: 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] - 1
      
  
# plotting the graph: 
pylab.title("Walking Ramdomly ($n = " + str(n) + "$ steps)") 
pylab.plot(x, y) 
#pylab.savefig("rand_walk"+str(n)+".png",bbox_inches="tight",dpi=600) 
pylab.show()

# %%
# Python code for 2D random walk. 
import numpy 
import pylab 
import random 
# %matplotlib inline
# defining the number of steps 
# for 100000 steps
n = 100000
  
#creating two array for containing x and y coordinate 
#of size equals to the number of size and filled up with 0's 
x = numpy.zeros(n) 
y = numpy.zeros(n) 
  
# filling the coordinates with random variables 
for i in range(1, n): 
    val = random.randint(1, 4) 
    if val == 1: 
        x[i] = x[i - 1] + 1
        y[i] = y[i - 1] 
    elif val == 2: 
        x[i] = x[i - 1] - 1
        y[i] = y[i - 1] 
    elif val == 3: 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] + 1
    else: 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] - 1
      
  
# plotting the graph: 
pylab.title("Walking Ramdomly ($n = " + str(n) + "$ steps)") 
pylab.plot(x, y) 
#pylab.savefig("rand_walk"+str(n)+".png",bbox_inches="tight",dpi=600) 
pylab.show()

# %%
# Python code for 2D random walk. 
import numpy 
import pylab 
import random 
# %matplotlib inline
# defining the number of steps 
# for 1000000 steps
n = 1000000
  
#creating two array for containing x and y coordinate 
#of size equals to the number of size and filled up with 0's 
x = numpy.zeros(n) 
y = numpy.zeros(n) 
  
# filling the coordinates with random variables 
for i in range(1, n): 
    val = random.randint(1, 4) 
    if val == 1: 
        x[i] = x[i - 1] + 1
        y[i] = y[i - 1] 
    elif val == 2: 
        x[i] = x[i - 1] - 1
        y[i] = y[i - 1] 
    elif val == 3: 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] + 1
    #elif val == 4: 
    #    x[i] = x[i - 1] 
    #    y[i] = y[i - 1] - 1
    else: 
        x[i] = x[i - 1] 
        y[i] = y[i - 1] - 1
      
  
# plotting the graph: 
pylab.title("Walking Ramdomly ($n = " + str(n) + "$ steps)") 
pylab.plot(x, y) 
#pylab.savefig("rand_walk"+str(n)+".png",bbox_inches="tight",dpi=600) 
pylab.show()
