# %% [markdown]
# <font size="5.5">*19210261 : CA682 Assignment 2019-20*</font>

# %%
import pandas as pd
lifeExp = pd.read_csv("C:\Users\Raghvendra\Desktop\CA682 Assignment 2019-20\life_expectancy.csv")
worldPop = pd.read_csv("C:\Users\Raghvendra\Desktop\CA682 Assignment 2019-20\World_Population.csv")
gdp = pd.read_csv("C:\Users\Raghvendra\Desktop\CA682 Assignment 2019-20\GDP_per_capita.csv")
# Out:
#   File "<ipython-input-206-97f1a15961ad>", line 2
#     lifeExp = pd.read_csv("C:\Users\Raghvendra\Desktop\CA682 Assignment 2019-20\life_expectancy.csv")
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
lifeExp = pd.read_csv("C:/Users/Raghvendra/Desktop/CA682 Assignment 2019-20/life_expectancy.csv")

# %%
worldPop = pd.read_csv("C:/Users/Raghvendra/Desktop/CA682 Assignment 2019-20/World_Population.csv")
gdp = pd.read_csv("C:/Users/Raghvendra/Desktop/CA682 Assignment 2019-20/GDP_per_capita.csv")

# %%
lifeExp.head()
# Out:
#         Entity Code  Year  Life expectancy (years)
# 0  Afghanistan  AFG  1950                   27.638
# 1  Afghanistan  AFG  1951                   27.878
# 2  Afghanistan  AFG  1952                   28.361
# 3  Afghanistan  AFG  1953                   28.852
# 4  Afghanistan  AFG  1954                   29.350

# %%
lifeExp2017 = lifeExp[lifeExp.Year == 2017]

# %%
lifeExp2017_colm = lifeExp2017[['Entity', 'Code', 'Year', 'Life expectancy (years)']]

# %%
lifeExp2017_colm.head(10)
# Out:
#              Entity Code  Year  Life expectancy (years)
# 67           Monaco  MCO  2017                   86.325
# 139      San Marino  SMR  2017                   84.699
# 209       Hong Kong  HKG  2017                   84.493
# 282           Japan  JPN  2017                   84.290
# 352           Macao  MAC  2017                   83.989
# 428  Cayman Islands  CYM  2017                   83.633
# 498     Switzerland  CHE  2017                   83.473
# 569         Andorra  AND  2017                   83.443
# 639           Spain  ESP  2017                   83.294
# 709       Singapore  SGP  2017                   83.279

# %%
worldPop2017 = worldPop[['Country Name', 'Country Code', '2017']]

# %%
worldPop2017.head()
# Out:
#   Country Name Country Code        2017
# 0        Aruba          ABW    105366.0
# 1  Afghanistan          AFG  36296400.0
# 2       Angola          AGO  29816748.0
# 3      Albania          ALB   2873457.0
# 4      Andorra          AND     77001.0

# %%
gdp2017 = gdp[['Country Name', 'Country Code', '2017']]

# %%
gdp2017.head()
# Out:
#   Country Name Country Code          2017
# 0        Aruba          ABW  35861.828120
# 1  Afghanistan          AFG   1758.465636
# 2       Angola          AGO   6044.972035
# 3      Albania          ALB  11803.281800
# 4      Andorra          AND  39134.000000

# %%
merged_1 = pd.merge(lifeExp2017_colm, worldPop2017 , left_on=['Entity'], right_on=['Country Name'], how='inner')

# %%
merged_1.head()
# Out:
#        Entity Code  Year  Life expectancy (years) Country Name Country Code  \
# 0      Monaco  MCO  2017                   86.325       Monaco          MCO
# 1  San Marino  SMR  2017                   84.699   San Marino          SMR
# 2   Hong Kong  HKG  2017                   84.493    Hong Kong          HKG
# 3       Japan  JPN  2017                   84.290        Japan          JPN
# 4       Macao  MAC  2017                   83.989        Macao          MAC
#
#           2017
# 0      38392.0
# 1      33671.0
# 2    7391700.0
# 3  126785797.0
# 4     622585.0

# %%
merged_1_afterRename = merged_1.rename({'2017':'Population'}, axis='columns')

# %%
gdp2017_afterRename = gdp2017.rename({'Country Name':'Country', 'Country Code':'Country Code in GDP', '2017':'GDP'}, axis=1)

# %%
merged_1_afterRename[merged_1_afterRename["Entity"] == "World"]
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Life expectancy (years), Country Name, Country Code, Population]
# Index: []

# %%
merged_1_afterRename.drop([117], axis=0)
# Out:
#                        Entity      Code  Year  Life expectancy (years)  \
# 0                      Monaco       MCO  2017                   86.325
# 1                  San Marino       SMR  2017                   84.699
# 2                   Hong Kong       HKG  2017                   84.493
# 3                       Japan       JPN  2017                   84.290
# 4                       Macao       MAC  2017                   83.989
# 5              Cayman Islands       CYM  2017                   83.633
# 6                 Switzerland       CHE  2017                   83.473
# 7                     Andorra       AND  2017                   83.443
# 8                       Spain       ESP  2017                   83.294
# 9                   Singapore       SGP  2017                   83.279
# 10                      Italy       ITA  2017                   83.184
# 11                  Australia       AUS  2017                   83.122
# 12            Channel Islands  OWID_CIS  2017                   82.766
# 13                    Iceland       ISL  2017                   82.725
# 14                     Israel       ISR  2017                   82.663
# 15                     Sweden       SWE  2017                   82.516
# 16                     France       FRA  2017                   82.432
# 17                    Bermuda       BMU  2017                   82.316
# 18              Liechtenstein       LIE  2017                   82.228
# 19                      Malta       MLT  2017                   82.221
# 20                     Canada       CAN  2017                   82.210
# 21                     Norway       NOR  2017                   82.146
# 22                Netherlands       NLD  2017                   82.004
# 23                New Zealand       NZL  2017                   82.002
# 24                 Luxembourg       LUX  2017                   81.955
# 25                     Greece       GRC  2017                   81.901
# 26                    Ireland       IRL  2017                   81.872
# 27                   Portugal       PRT  2017                   81.655
# 28                    Finland       FIN  2017                   81.561
# 29                    Austria       AUT  2017                   81.340
# ..                        ...       ...   ...                      ...
# 158              South Africa       ZAF  2017                   63.538
# 159                     Ghana       GHA  2017                   63.463
# 160                   Liberia       LBR  2017                   63.295
# 161                     Haiti       HTI  2017                   63.290
# 162                    Malawi       MWI  2017                   63.279
# 163                    Zambia       ZMB  2017                   63.043
# 164                   Namibia       NAM  2017                   63.021
# 165                    Uganda       UGA  2017                   62.516
# 166                     Niger       NER  2017                   61.599
# 167                     Benin       BEN  2017                   61.174
# 168                   Burundi       BDI  2017                   60.898
# 169                  Zimbabwe       ZWE  2017                   60.812
# 170              Burkina Faso       BFA  2017                   60.768
# 171                    Guinea       GIN  2017                   60.706
# 172                      Togo       TGO  2017                   60.489
# 173                    Angola       AGO  2017                   60.379
# 174                     Nauru       NRU  2017                   59.805
# 175                Mozambique       MOZ  2017                   59.309
# 176                  Cameroon       CMR  2017                   58.511
# 177                      Mali       MLI  2017                   58.452
# 178         Equatorial Guinea       GNQ  2017                   58.061
# 179             Guinea-Bissau       GNB  2017                   57.673
# 180               South Sudan       SSD  2017                   57.365
# 181             Cote d'Ivoire       CIV  2017                   57.017
# 182                   Somalia       SOM  2017                   56.709
# 183                   Nigeria       NGA  2017                   53.950
# 184              Sierra Leone       SLE  2017                   53.895
# 185                      Chad       TCD  2017                   53.712
# 186                   Lesotho       LSO  2017                   52.947
# 187  Central African Republic       CAF  2017                   52.240
#
#                  Country Name Country Code   Population
# 0                      Monaco          MCO      38392.0
# 1                  San Marino          SMR      33671.0
# 2                   Hong Kong          HKG    7391700.0
# 3                       Japan          JPN  126785797.0
# 4                       Macao          MAC     622585.0
# 5              Cayman Islands          CYM      63382.0
# 6                 Switzerland          CHE    8451840.0
# 7                     Andorra          AND      77001.0
# 8                       Spain          ESP   46593236.0
# 9                   Singapore          SGP    5612253.0
# 10                      Italy          ITA   60536709.0
# 11                  Australia          AUS   24601860.0
# 12            Channel Islands          CHI     168665.0
# 13                    Iceland          ISL     343400.0
# 14                     Israel          ISR    8713300.0
# 15                     Sweden          SWE   10057698.0
# 16                     France          FRA   66865144.0
# 17                    Bermuda          BMU      63874.0
# 18              Liechtenstein          LIE      37800.0
# 19                      Malta          MLT     467999.0
# 20                     Canada          CAN   36540268.0
# 21                     Norway          NOR    5276968.0
# 22                Netherlands          NLD   17131296.0
# 23                New Zealand          NZL    4793900.0
# 24                 Luxembourg          LUX     596336.0
# 25                     Greece          GRC   10754679.0
# 26                    Ireland          IRL    4807388.0
# 27                   Portugal          PRT   10300300.0
# 28                    Finland          FIN    5508214.0
# 29                    Austria          AUT    8797566.0
# ..                        ...          ...          ...
# 158              South Africa          ZAF   57000451.0
# 159                     Ghana          GHA   29121471.0
# 160                   Liberia          LBR    4702228.0
# 161                     Haiti          HTI   10982366.0
# 162                    Malawi          MWI   17670260.0
# 163                    Zambia          ZMB   16853688.0
# 164                   Namibia          NAM    2402603.0
# 165                    Uganda          UGA   41162465.0
# 166                     Niger          NER   21602472.0
# 167                     Benin          BEN   11175204.0
# 168                   Burundi          BDI   10827024.0
# 169                  Zimbabwe          ZWE   14236745.0
# 170              Burkina Faso          BFA   19193284.0
# 171                    Guinea          GIN   12067539.0
# 172                      Togo          TGO    7698475.0
# 173                    Angola          AGO   29816748.0
# 174                     Nauru          NRU      12876.0
# 175                Mozambique          MOZ   28649007.0
# 176                  Cameroon          CMR   24566045.0
# 177                      Mali          MLI   18512394.0
# 178         Equatorial Guinea          GNQ    1262001.0
# 179             Guinea-Bissau          GNB    1828146.0
# 180               South Sudan          SSD   10910759.0
# 181             Cote d'Ivoire          CIV   24437469.0
# 182                   Somalia          SOM   14589119.0
# 183                   Nigeria          NGA  190873311.0
# 184              Sierra Leone          SLE    7488431.0
# 185                      Chad          TCD   15016773.0
# 186                   Lesotho          LSO    2091412.0
# 187  Central African Republic          CAF    4596028.0
#
# [187 rows x 7 columns]

# %%
merged_2 = pd.merge(merged_1_afterRename, gdp2017_afterRename , left_on=['Entity'], right_on=['Country'], how='inner')

# %%
merged_2.count()
# Out:
# Entity                     188
# Code                       188
# Year                       188
# Life expectancy (years)    188
# Country Name               188
# Country Code               188
# Population                 187
# Country                    188
# Country Code in GDP        188
# GDP                        170
# dtype: int64

# %%
merged_2.sort_values('Life expectancy (years)').head()
# Out:
#                        Entity Code  Year  Life expectancy (years)  \
# 187  Central African Republic  CAF  2017                   52.240
# 186                   Lesotho  LSO  2017                   52.947
# 185                      Chad  TCD  2017                   53.712
# 184              Sierra Leone  SLE  2017                   53.895
# 183                   Nigeria  NGA  2017                   53.950
#
#                  Country Name Country Code   Population  \
# 187  Central African Republic          CAF    4596028.0
# 186                   Lesotho          LSO    2091412.0
# 185                      Chad          TCD   15016773.0
# 184              Sierra Leone          SLE    7488431.0
# 183                   Nigeria          NGA  190873311.0
#
#                       Country Country Code in GDP          GDP
# 187  Central African Republic                 CAF   753.824879
# 186                   Lesotho                 LSO  2845.889522
# 185                      Chad                 TCD  1753.771876
# 184              Sierra Leone                 SLE  1403.791088
# 183                   Nigeria                 NGA  5351.441254

# %%
merged_2.sort_values('Life expectancy (years)', ascending=False).head(10)
# Out:
#            Entity Code  Year  Life expectancy (years)    Country Name  \
# 0          Monaco  MCO  2017                   86.325          Monaco
# 1      San Marino  SMR  2017                   84.699      San Marino
# 2       Hong Kong  HKG  2017                   84.493       Hong Kong
# 3           Japan  JPN  2017                   84.290           Japan
# 4           Macao  MAC  2017                   83.989           Macao
# 5  Cayman Islands  CYM  2017                   83.633  Cayman Islands
# 6     Switzerland  CHE  2017                   83.473     Switzerland
# 7         Andorra  AND  2017                   83.443         Andorra
# 8           Spain  ESP  2017                   83.294           Spain
# 9       Singapore  SGP  2017                   83.279       Singapore
#
#   Country Code   Population         Country Country Code in GDP           GDP
# 0          MCO      38392.0          Monaco                 MCO  166726.00000
# 1          SMR      33671.0      San Marino                 SMR   57296.86426
# 2          HKG    7391700.0       Hong Kong                 HKG   56087.69343
# 3          JPN  126785797.0           Japan                 JPN   38907.36814
# 4          MAC     622585.0           Macao                 MAC  105448.67700
# 5          CYM      63382.0  Cayman Islands                 CYM   65995.80985
# 6          CHE    8451840.0     Switzerland                 CHE   57997.64349
# 7          AND      77001.0         Andorra                 AND   39134.00000
# 8          ESP   46593236.0           Spain                 ESP   34269.11624
# 9          SGP    5612253.0       Singapore                 SGP   87760.36815

# %%
forGraph1_1 = merged_2.sort_values('Life expectancy (years)', ascending=False).head(10)

# %%
lifeExp1987 = lifeExp[lifeExp.Year == 1987]

# %%
lifeExp1987_colm = lifeExp1987[['Entity', 'Code', 'Year', 'Life expectancy (years)']]

# %%
lifeExp1987_before_final = lifeExp1987_colm[(lifeExp1987_colm.Entity == 'Monaco') | (lifeExp1987_colm.Entity == 'San Marino') | (lifeExp1987_colm.Entity == 'Hong Kong')| (lifeExp1987_colm.Entity == 'Japan')| (lifeExp1987_colm.Entity == 'Macao') | (lifeExp1987_colm.Entity == 'Cayman Islands')| (lifeExp1987_colm.Entity == 'Switzerland') | (lifeExp1987_colm.Entity == 'Andorra')| (lifeExp1987_colm.Entity == 'Spain')| (lifeExp1987_colm.Entity == 'Singapore')]

# %%
lifeExp1987_final=lifeExp1987_before_final.rename({'Entity':'Entity 1987'}, axis='columns')

# %%
lifeExp1987_final.head(2)
# Out:
#          Entity 1987 Code  Year  Life expectancy (years)
# 468          Andorra  AND  1987                   76.097
# 3152  Cayman Islands  CYM  1987                   73.963

# %%
dataForGraph_1 = pd.merge(forGraph1_1, lifeExp1987_final , left_on=['Entity'], right_on=['Entity 1987'], how='inner')

# %%
dataForGraph_1.head(11)
# Out:
#            Entity Code_x  Year_x  Life expectancy (years)_x    Country Name  \
# 0          Monaco    MCO    2017                     86.325          Monaco
# 1      San Marino    SMR    2017                     84.699      San Marino
# 2       Hong Kong    HKG    2017                     84.493       Hong Kong
# 3           Japan    JPN    2017                     84.290           Japan
# 4           Macao    MAC    2017                     83.989           Macao
# 5  Cayman Islands    CYM    2017                     83.633  Cayman Islands
# 6     Switzerland    CHE    2017                     83.473     Switzerland
# 7         Andorra    AND    2017                     83.443         Andorra
# 8           Spain    ESP    2017                     83.294           Spain
# 9       Singapore    SGP    2017                     83.279       Singapore
#
#   Country Code   Population         Country Country Code in GDP           GDP  \
# 0          MCO      38392.0          Monaco                 MCO  166726.00000
# 1          SMR      33671.0      San Marino                 SMR   57296.86426
# 2          HKG    7391700.0       Hong Kong                 HKG   56087.69343
# 3          JPN  126785797.0           Japan                 JPN   38907.36814
# 4          MAC     622585.0           Macao                 MAC  105448.67700
# 5          CYM      63382.0  Cayman Islands                 CYM   65995.80985
# 6          CHE    8451840.0     Switzerland                 CHE   57997.64349
# 7          AND      77001.0         Andorra                 AND   39134.00000
# 8          ESP   46593236.0           Spain                 ESP   34269.11624
# 9          SGP    5612253.0       Singapore                 SGP   87760.36815
#
#       Entity 1987 Code_y  Year_y  Life expectancy (years)_y
# 0          Monaco    MCO    1987                     76.616
# 1      San Marino    SMR    1987                     78.814
# 2       Hong Kong    HKG    1987                     76.822
# 3           Japan    JPN    1987                     78.372
# 4           Macao    MAC    1987                     76.363
# 5  Cayman Islands    CYM    1987                     73.963
# 6     Switzerland    CHE    1987                     77.082
# 7         Andorra    AND    1987                     76.097
# 8           Spain    ESP    1987                     76.822
# 9       Singapore    SGP    1987                     74.762

# %%
import matplotlib.ticker as ticker
import numpy as np
import matplotlib.pyplot as plt

# data to plot
#n_groups = 10
#means_frank = (90, 55, 40, 65)
#means_guido = (85, 62, 54, 20)

tick_spacing = 3

# create plot
fig, ax = plt.subplots(figsize=(10,7))
ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
index = np.arange(10)
bar_width = .45
opacity = 0.8
ax.set_axisbelow(True)
ax.grid(color='whitesmoke')

#rects1 = plt.bar(index, dataForGraph_1['Life expectancy (years)_x'], bar_width, alpha=opacity,color='yellow',label='2017')
rects1 = plt.bar(index, dataForGraph_1['Life expectancy (years)_x'], bar_width, alpha=opacity,color='c',label='2017')

#rects2 = plt.bar(index + bar_width, dataForGraph_1['Life expectancy (years)_y'], bar_width, alpha=opacity, color='k', label='1987')
rects2 = plt.bar(index + bar_width, dataForGraph_1['Life expectancy (years)_y'], bar_width, alpha=opacity, color='lightblue', label='1987')

plt.ylim(0, 95)
plt.xlabel('Countries with highest life expectancy',fontsize=13.5)
plt.ylabel('Life expectancy (in years)',fontsize=13.5)
#plt.figtext(0.47, 0.99, "2017", fontsize='medium', color='k', ha ='right')
#plt.figtext(0.47, 0.96, "1987", fontsize='medium', color='c', ha ='left')
plt.title('Life expectancy comparision between 2017 and 1987',fontsize=15)
plt.xticks(index + bar_width/2,('Monaco', 'San Marino', 'Hong Kong', 'Japan', 'Macao', 'Cayman Islands', 'Switzerland', 'Andorra', 'Spain', 'Singapore'), rotation='90')
plt.legend()

#plt.tight_layout()
plt.show()

# %%
#merged_2_updated = merged_2['GDP'].replace('', np.nan, inplace=True)
#merged_2_updated.dropna(subset=['GDP'], inplace=True)
fig, ax = plt.subplots(figsize=(10, 7))
ax.grid(color='whitesmoke')
colors = np.random.rand(188) 
plt.xlim(0,120)
#plt.ylim(-1, 1)
plt.xlabel('GDP per capita (in per 1000 US $)',fontsize=13.5)
plt.ylabel('Life Expectancy (in years)',fontsize=13.5)
plt.title('Life expectancy Vs GDP in 2017',fontsize=15)
# use the scatter function
plt.scatter(x=merged_2['GDP']/1000,y=merged_2['Life expectancy (years)'],s=merged_2['Population']/1000000, marker="o",c=colors)
plt.show()

# %%
fig, ax = plt.subplots()
ax.grid(color='grey')
colors = np.random.rand(10) 
plt.xlabel('GDP per capita')
plt.ylabel('Life Expectancy (in years)')
plt.title('Life expectancy with GDP')
# use the scatter function
plt.scatter(x=forGraph1_1['GDP']/1000,y=forGraph1_1['Life expectancy (years)'],s=forGraph1_1['Population']/100000, marker="8", c=colors)
plt.show()

# %%
forGraph3 = merged_2.sort_values('Life expectancy (years)', ascending=True).head(10)

# %%
forGraph3
# Out:
#                        Entity Code  Year  Life expectancy (years)  \
# 187  Central African Republic  CAF  2017                   52.240
# 186                   Lesotho  LSO  2017                   52.947
# 185                      Chad  TCD  2017                   53.712
# 184              Sierra Leone  SLE  2017                   53.895
# 183                   Nigeria  NGA  2017                   53.950
# 182                   Somalia  SOM  2017                   56.709
# 181             Cote d'Ivoire  CIV  2017                   57.017
# 180               South Sudan  SSD  2017                   57.365
# 179             Guinea-Bissau  GNB  2017                   57.673
# 178         Equatorial Guinea  GNQ  2017                   58.061
#
#                  Country Name Country Code   Population  \
# 187  Central African Republic          CAF    4596028.0
# 186                   Lesotho          LSO    2091412.0
# 185                      Chad          TCD   15016773.0
# 184              Sierra Leone          SLE    7488431.0
# 183                   Nigeria          NGA  190873311.0
# 182                   Somalia          SOM   14589119.0
# 181             Cote d'Ivoire          CIV   24437469.0
# 180               South Sudan          SSD   10910759.0
# 179             Guinea-Bissau          GNB    1828146.0
# 178         Equatorial Guinea          GNQ    1262001.0
#
#                       Country Country Code in GDP           GDP
# 187  Central African Republic                 CAF    753.824879
# 186                   Lesotho                 LSO   2845.889522
# 185                      Chad                 TCD   1753.771876
# 184              Sierra Leone                 SLE   1403.791088
# 183                   Nigeria                 NGA   5351.441254
# 182                   Somalia                 SOM           NaN
# 181             Cote d'Ivoire                 CIV   3564.595846
# 180               South Sudan                 SSD           NaN
# 179             Guinea-Bissau                 GNB   1576.748994
# 178         Equatorial Guinea                 GNQ  22298.942140

# %%
lifeExp1987_before_final = lifeExp1987_colm[(lifeExp1987_colm.Entity == 'Central African Republic') | (lifeExp1987_colm.Entity == 'Lesotho') | (lifeExp1987_colm.Entity == 'Chad')| (lifeExp1987_colm.Entity == 'Sierra Leone')| (lifeExp1987_colm.Entity == 'Nigeria') | (lifeExp1987_colm.Entity == 'Somalia')| (lifeExp1987_colm.Entity == "Cote d'Ivoire") | (lifeExp1987_colm.Entity == 'South Sudan')| (lifeExp1987_colm.Entity == 'Guinea-Bissau')| (lifeExp1987_colm.Entity == 'Equatorial Guinea')]

# %%
lifeExp1987_final=lifeExp1987_before_final.rename({'Entity':'Entity 1987'}, axis='columns')

# %%
#lifeExp1987_final
dataForGraph_3 = pd.merge(forGraph3, lifeExp1987_final , left_on=['Entity'], right_on=['Entity 1987'], how='inner')

# %%
dataForGraph_3
# Out:
#                      Entity Code_x  Year_x  Life expectancy (years)_x  \
# 0  Central African Republic    CAF    2017                     52.240
# 1                   Lesotho    LSO    2017                     52.947
# 2                      Chad    TCD    2017                     53.712
# 3              Sierra Leone    SLE    2017                     53.895
# 4                   Nigeria    NGA    2017                     53.950
# 5                   Somalia    SOM    2017                     56.709
# 6             Cote d'Ivoire    CIV    2017                     57.017
# 7               South Sudan    SSD    2017                     57.365
# 8             Guinea-Bissau    GNB    2017                     57.673
# 9         Equatorial Guinea    GNQ    2017                     58.061
#
#                Country Name Country Code   Population  \
# 0  Central African Republic          CAF    4596028.0
# 1                   Lesotho          LSO    2091412.0
# 2                      Chad          TCD   15016773.0
# 3              Sierra Leone          SLE    7488431.0
# 4                   Nigeria          NGA  190873311.0
# 5                   Somalia          SOM   14589119.0
# 6             Cote d'Ivoire          CIV   24437469.0
# 7               South Sudan          SSD   10910759.0
# 8             Guinea-Bissau          GNB    1828146.0
# 9         Equatorial Guinea          GNQ    1262001.0
#
#                     Country Country Code in GDP           GDP  \
# 0  Central African Republic                 CAF    753.824879
# 1                   Lesotho                 LSO   2845.889522
# 2                      Chad                 TCD   1753.771876
# 3              Sierra Leone                 SLE   1403.791088
# 4                   Nigeria                 NGA   5351.441254
# 5                   Somalia                 SOM           NaN
# 6             Cote d'Ivoire                 CIV   3564.595846
# 7               South Sudan                 SSD           NaN
# 8             Guinea-Bissau                 GNB   1576.748994
# 9         Equatorial Guinea                 GNQ  22298.942140
#
#                 Entity 1987 Code_y  Year_y  Life expectancy (years)_y
# 0  Central African Republic    CAF    1987                     49.797
# 1                   Lesotho    LSO    1987                     59.868
# 2                      Chad    TCD    1987                     46.601
# 3              Sierra Leone    SLE    1987                     39.827
# 4                   Nigeria    NGA    1987                     46.048
# 5                   Somalia    SOM    1987                     46.115
# 6             Cote d'Ivoire    CIV    1987                     53.286
# 7               South Sudan    SSD    1987                     41.513
# 8             Guinea-Bissau    GNB    1987                     46.190
# 9         Equatorial Guinea    GNQ    1987                     47.630

# %%
import matplotlib.ticker as ticker
import numpy as np
import matplotlib.pyplot as plt
#import matplotlib.pyplot as plt2

# data to plot
#n_groups = 10
#means_frank = (90, 55, 40, 65)
#means_guido = (85, 62, 54, 20)
tick_spacing = 3
fig = plt.figure(figsize=(14,7))
ax2 = fig.add_subplot(1,2,1)
ax2.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
index = np.arange(10)
bar_width = .45
opacity = 0.8
ax2.set_axisbelow(True)
ax2.grid(color='whitesmoke')

#rects1 = plt.bar(index, dataForGraph_1['Life expectancy (years)_x'], bar_width, alpha=opacity,color='yellow',label='2017')
rects1 = plt.bar(index, dataForGraph_1['Life expectancy (years)_x'], bar_width, alpha=opacity,color='c',label='2017')

#rects2 = plt.bar(index + bar_width, dataForGraph_1['Life expectancy (years)_y'], bar_width, alpha=opacity, color='k', label='1987')
rects2 = plt.bar(index + bar_width, dataForGraph_1['Life expectancy (years)_y'], bar_width, alpha=opacity, color='lightblue', label='1987')

plt.ylim(0, 95)
plt.xlabel('Countries with highest life expectancy',fontsize=13.5)
plt.ylabel('Life expectancy (in years)',fontsize=13.5)
#plt.figtext(0.47, 0.99, "2017", fontsize='medium', color='k', ha ='right')
#plt.figtext(0.47, 0.96, "1987", fontsize='medium', color='c', ha ='left')
plt.title('Comparing life expectancy between 2017 and 1987',fontsize=15)
plt.xticks(index + bar_width/2,('Monaco', 'San Marino', 'Hong Kong', 'Japan', 'Macao', 'Cayman Islands', 'Switzerland', 'Andorra', 'Spain', 'Singapore'), rotation='90')
plt.legend()

#plt.tight_layout()
#plt.show()

#----------------------------------------------------------------------------------------------


# create plot
#fig = plt.figure()
#fig = plt.figure(figsize=(10,7))
ax = fig.add_subplot(1,2,2)
#ax2 = fig.add_subplot(1,2,2)
#fig, ax = plt.subplots(figsize=(10,7),sharex='True')
#fig, ax = plt.subplots(121,50)
index = np.arange(10)
bar_width = .45
opacity = 0.8
ax.set_axisbelow(True)
ax.grid(color='whitesmoke')
tick_spacing = 3
ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
#rects1 = plt.bar(index, dataForGraph_1['Life expectancy (years)_x'], bar_width, alpha=opacity,color='yellow',label='2017')
rects3 = plt.bar(index, dataForGraph_3['Life expectancy (years)_x'], bar_width, alpha=opacity,color='darkorange',label='2017')



#rects2 = plt.bar(index + bar_width, dataForGraph_1['Life expectancy (years)_y'], bar_width, alpha=opacity, color='k', label='1987')
rects4 = plt.bar(index + bar_width, dataForGraph_3['Life expectancy (years)_y'], bar_width, alpha=opacity, color='moccasin', label='1987')

plt.ylim(0,95)
plt.xlabel('Countries with lowest life expectancy',fontsize=13.5)
plt.ylabel('Life expectancy (in years)',fontsize=13.5)
#plt.figtext(0.47, 0.99, "2017", fontsize='medium', color='k', ha ='right')
#plt.figtext(0.47, 0.96, "1987", fontsize='medium', color='c', ha ='left')
plt.title('Comparing life expectancy between 2017 and 1987',fontsize=15)
plt.xticks(index + bar_width/2,('Central African Republic', 'Chad', "Cote d'Ivoire", 'Equatorial Guinea', 'Guinea-Bissau', 'Lesotho', 'Nigeria', 'Sierra Leone', 'Somalia', 'South Sudan'), rotation='90')
plt.legend()
plt.show()

# %%
test = pd.concat([dataForGraph_1,dataForGraph_3],ignore_index=True)

# %%
test
# Out:
#                       Entity Code_x  Year_x  Life expectancy (years)_x  \
# 0                     Monaco    MCO    2017                     86.325
# 1                 San Marino    SMR    2017                     84.699
# 2                  Hong Kong    HKG    2017                     84.493
# 3                      Japan    JPN    2017                     84.290
# 4                      Macao    MAC    2017                     83.989
# 5             Cayman Islands    CYM    2017                     83.633
# 6                Switzerland    CHE    2017                     83.473
# 7                    Andorra    AND    2017                     83.443
# 8                      Spain    ESP    2017                     83.294
# 9                  Singapore    SGP    2017                     83.279
# 10  Central African Republic    CAF    2017                     52.240
# 11                   Lesotho    LSO    2017                     52.947
# 12                      Chad    TCD    2017                     53.712
# 13              Sierra Leone    SLE    2017                     53.895
# 14                   Nigeria    NGA    2017                     53.950
# 15                   Somalia    SOM    2017                     56.709
# 16             Cote d'Ivoire    CIV    2017                     57.017
# 17               South Sudan    SSD    2017                     57.365
# 18             Guinea-Bissau    GNB    2017                     57.673
# 19         Equatorial Guinea    GNQ    2017                     58.061
#
#                 Country Name Country Code   Population  \
# 0                     Monaco          MCO      38392.0
# 1                 San Marino          SMR      33671.0
# 2                  Hong Kong          HKG    7391700.0
# 3                      Japan          JPN  126785797.0
# 4                      Macao          MAC     622585.0
# 5             Cayman Islands          CYM      63382.0
# 6                Switzerland          CHE    8451840.0
# 7                    Andorra          AND      77001.0
# 8                      Spain          ESP   46593236.0
# 9                  Singapore          SGP    5612253.0
# 10  Central African Republic          CAF    4596028.0
# 11                   Lesotho          LSO    2091412.0
# 12                      Chad          TCD   15016773.0
# 13              Sierra Leone          SLE    7488431.0
# 14                   Nigeria          NGA  190873311.0
# 15                   Somalia          SOM   14589119.0
# 16             Cote d'Ivoire          CIV   24437469.0
# 17               South Sudan          SSD   10910759.0
# 18             Guinea-Bissau          GNB    1828146.0
# 19         Equatorial Guinea          GNQ    1262001.0
#
#                      Country Country Code in GDP            GDP  \
# 0                     Monaco                 MCO  166726.000000
# 1                 San Marino                 SMR   57296.864260
# 2                  Hong Kong                 HKG   56087.693430
# 3                      Japan                 JPN   38907.368140
# 4                      Macao                 MAC  105448.677000
# 5             Cayman Islands                 CYM   65995.809850
# 6                Switzerland                 CHE   57997.643490
# 7                    Andorra                 AND   39134.000000
# 8                      Spain                 ESP   34269.116240
# 9                  Singapore                 SGP   87760.368150
# 10  Central African Republic                 CAF     753.824879
# 11                   Lesotho                 LSO    2845.889522
# 12                      Chad                 TCD    1753.771876
# 13              Sierra Leone                 SLE    1403.791088
# 14                   Nigeria                 NGA    5351.441254
# 15                   Somalia                 SOM            NaN
# 16             Cote d'Ivoire                 CIV    3564.595846
# 17               South Sudan                 SSD            NaN
# 18             Guinea-Bissau                 GNB    1576.748994
# 19         Equatorial Guinea                 GNQ   22298.942140
#
#                  Entity 1987 Code_y  Year_y  Life expectancy (years)_y
# 0                     Monaco    MCO    1987                     76.616
# 1                 San Marino    SMR    1987                     78.814
# 2                  Hong Kong    HKG    1987                     76.822
# 3                      Japan    JPN    1987                     78.372
# 4                      Macao    MAC    1987                     76.363
# 5             Cayman Islands    CYM    1987                     73.963
# 6                Switzerland    CHE    1987                     77.082
# 7                    Andorra    AND    1987                     76.097
# 8                      Spain    ESP    1987                     76.822
# 9                  Singapore    SGP    1987                     74.762
# 10  Central African Republic    CAF    1987                     49.797
# 11                   Lesotho    LSO    1987                     59.868
# 12                      Chad    TCD    1987                     46.601
# 13              Sierra Leone    SLE    1987                     39.827
# 14                   Nigeria    NGA    1987                     46.048
# 15                   Somalia    SOM    1987                     46.115
# 16             Cote d'Ivoire    CIV    1987                     53.286
# 17               South Sudan    SSD    1987                     41.513
# 18             Guinea-Bissau    GNB    1987                     46.190
# 19         Equatorial Guinea    GNQ    1987                     47.630

# %%
import matplotlib.ticker as ticker
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,7))
index = np.arange(20)
bar_width = .45
opacity = 0.8
ax.set_axisbelow(True)
ax.grid(color='whitesmoke')
tick_spacing = 3
ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
#rects1 = plt.bar(index, dataForGraph_1['Life expectancy (years)_x'], bar_width, alpha=opacity,color='yellow',label='2017')
rects3 = plt.bar(index, test['Life expectancy (years)_x'], bar_width, alpha=opacity,color='darkorange',label='2017')
#rects5 = plt.bar(index + 10, test['Life expectancy (years)_x'], bar_width, alpha=opacity,color='c',label='2017')



#rects2 = plt.bar(index + bar_width, dataForGraph_1['Life expectancy (years)_y'], bar_width, alpha=opacity, color='k', label='1987')
rects4 = plt.bar(index + bar_width, test['Life expectancy (years)_y'], bar_width, alpha=opacity, color='moccasin', label='1987')
#rects6 = plt.bar(index + bar_width, test['Life expectancy (years)_y'], bar_width, alpha=opacity, color='lightblue', label='1987')

plt.ylim(0,90)
plt.xlabel('Countries with highest and lowest life expectancy',fontsize=13.5)
plt.ylabel('Life expectancy (in years)',fontsize=13.5)
#plt.figtext(0.47, 0.99, "2017", fontsize='medium', color='k', ha ='right')
#plt.figtext(0.47, 0.96, "1987", fontsize='medium', color='c', ha ='left')
plt.title('Life expectancy comparision between 2017 and 1987',fontsize=15)
plt.xticks(index + bar_width/2,('Monaco', 'San Marino', 'Hong Kong', 'Japan', 'Macao', 'Cayman Islands', 'Switzerland', 'Andorra', 'Spain', 'Singapore','Central African Republic', 'Chad', "Cote d'Ivoire", 'Equatorial Guinea', 'Guinea-Bissau', 'Lesotho', 'Nigeria', 'Sierra Leone', 'Somalia', 'South Sudan'), rotation='90')
plt.legend()
plt.show()

# %%
import matplotlib.ticker as ticker
import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15,7))
index = np.arange(10)
index1 = np.arange(10)
bar_width = .45
opacity = 0.8
ax.set_axisbelow(True)
ax.grid(color='whitesmoke')
tick_spacing = 3
ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
#rects1 = plt.bar(index, dataForGraph_1['Life expectancy (years)_x'], bar_width, alpha=opacity,color='yellow',label='2017')
rects3 = plt.bar(index,dataForGraph_1['Life expectancy (years)_x'], bar_width, alpha=opacity,color='darkorange',label='2017')
#rects5 = plt.bar(index + 10, test['Life expectancy (years)_x'], bar_width, alpha=opacity,color='c',label='2017')
#dataForGraph_1,dataForGraph_3
rects3 = plt.bar(10 + index1,dataForGraph_3['Life expectancy (years)_x'], bar_width, alpha=opacity,color='c',label='2017')


#rects2 = plt.bar(index + bar_width, dataForGraph_1['Life expectancy (years)_y'], bar_width, alpha=opacity, color='k', label='1987')
#rects4 = plt.bar(index + bar_width, test['Life expectancy (years)_y'], bar_width, alpha=opacity, color='moccasin', label='1987')
#rects6 = plt.bar(10 + index1 + bar_width, test['Life expectancy (years)_y'], bar_width, alpha=opacity, color='lightblue', label='1987')

plt.ylim(0,90)
plt.xlabel('Countries with highest and lowest life expectancy',fontsize=13.5)
plt.ylabel('Life expectancy (in years)',fontsize=13.5)
#plt.figtext(0.47, 0.99, "2017", fontsize='medium', color='k', ha ='right')
#plt.figtext(0.47, 0.96, "1987", fontsize='medium', color='c', ha ='left')
plt.title('Life expectancy comparision between 2017 and 1987',fontsize=15)
#plt.xticks(index + bar_width/2,('Monaco', 'San Marino', 'Hong Kong', 'Japan', 'Macao', 'Cayman Islands', 'Switzerland', 'Andorra', 'Spain', 'Singapore'), rotation='90')
plt.xticks(index + bar_width/2,('Monaco', 'San Marino', 'Hong Kong', 'Japan', 'Macao', 'Cayman Islands', 'Switzerland', 'Andorra', 'Spain', 'Singapore','Central African Republic', 'Chad', "Cote d'Ivoire", 'Equatorial Guinea', 'Guinea-Bissau', 'Lesotho', 'Nigeria', 'Sierra Leone', 'Somalia', 'South Sudan'), rotation='90')
#plt.xticks(10 + index1 + bar_width/2,('Central African Republic', 'Chad', "Cote d'Ivoire", 'Equatorial Guinea', 'Guinea-Bissau', 'Lesotho', 'Nigeria', 'Sierra Leone', 'Somalia', 'South Sudan'), rotation='90')
plt.legend()
plt.show()
