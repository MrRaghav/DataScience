# %% [markdown]
# reference:
#
# https://www.tutorialspoint.com/seaborn/seaborn_histogram.htm

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

# %%
df = sb.load_dataset('iris')

# %%
sb.distplot(df['petal_length'],kde = False) #representation of the kernel estimation plot has been removed
plt.show()

# %%
sb.distplot(df['petal_length'],kde = True)
plt.show()
