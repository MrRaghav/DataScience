# %% [markdown]
# reference:
#
# https://www.tutorialspoint.com/seaborn/seaborn_statistical_estimation.htm

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

# %%
df = sb.load_dataset('titanic')

# %% [markdown]
# But when it comes to **central tendency estimation** , we need a specific way to summarize the distribution. Mean and median are the very often used techniques to estimate the central tendency of the distribution.

# %% [markdown]
# barplot() shows the relation between a categorical variable and a continuous variable. The data is represented in rectangular bars where the length the bar represents the proportion of the data in that category.
#
# Bar plot represents the estimate of central tendency.

# %%
sb.barplot(x = "sex", y = "survived", hue = "class", data = df)
plt.show()

# %% [markdown]
# special case in barplot is to show the no of observations in each category rather than computing a statistic for a second variable. For this, we use countplot().

# %%
sb.countplot(x = "class", data = df, palette = "Blues");
plt.show()

# %% [markdown]
# **Point plots** serve same as bar plots but in a different style. Rather than the full bar, the value of the estimate is represented by the point at a certain height on the other axis

# %%
sb.pointplot(x = "sex", y = "survived", hue = "class", data = df)
plt.show()
