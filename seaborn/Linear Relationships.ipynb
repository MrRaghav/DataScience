# %% [markdown]
# reference:
#
# https://www.tutorialspoint.com/seaborn/seaborn_linear_relationships.htm

# %% [markdown]
# While building the regression models, we often check for multicollinearity, where we had to see the correlation between all the combinations of continuous variables and will take necessary action to remove multicollinearity if exists

# %% [markdown]
# There are two main functions in Seaborn to visualize a linear relationship determined through regression. These functions are **regplot()** and **lmplot()**

# %% [markdown]
# regplot --
# accepts the x and y variables in a variety of formats including simple numpy arrays, pandas Series objects, or as references to variables in a pandas DataFrame
#
# lmplot --
# has data as a required parameter and the x and y variables must be specified as strings. This data format is called “long-form” data

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt

# %%
df = sb.load_dataset('tips')

# %%
sb.regplot(x = "total_bill", y = "tip", data = df)
sb.lmplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %% [markdown]
# We can see the difference in the size between two plots.

# %% [markdown]
# We can also fit a linear regression when one of the variables takes discrete values

# %%
sb.lmplot(x = "size", y = "tip", data = df)
plt.show()

# %% [markdown]
# _Fitting Different Kinds of Models_
#
#
# The simple linear regression model used above is very simple to fit, but in most of the cases, the data is non-linear and the above methods cannot generalize the regression line.

# %%
df = sb.load_dataset('anscombe')

# %%
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %%
sb.lmplot(x="x", y="y", data=df.query("dataset == 'I'"))
plt.show()

# %% [markdown]
# In this case, the data is good fit for linear regression model with less variance

# %%
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"))
plt.show()

# %% [markdown]
# above is another example where the data takes high deviation which shows the line of best fit is not good.

# %% [markdown]
# Below plot shows the high deviation of data points from the regression line. Such non-linear, higher order can be visualized using the lmplot() and regplot().These can fit a polynomial regression model to explore simple kinds of nonlinear trends in the dataset −

# %%
sb.lmplot(x = "x", y = "y", data = df.query("dataset == 'II'"),order = 2)
plt.show()
