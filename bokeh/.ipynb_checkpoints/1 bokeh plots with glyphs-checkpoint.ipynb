# %% [markdown]
# reference:
#
# https://www.tutorialspoint.com/bokeh/bokeh_plots_with_glyphs.htm

# %% [markdown]
# Simple Line plot

# %%
from bokeh.plotting import figure, output_file, output_notebook, show

x = [1,2,3,4,5]
y = [2,4,6,8,10]
#output_file('line.html')
output_notebook()  #just for jupyter notebook
fig = figure(title = 'Line Plot example', x_axis_label = 'x', y_axis_label = 'y')
fig.line(x,y)
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1113">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b54dddf8-8d88-4f80-a07a-8c930f33d98d" data-root-id="1114"></div>

# %%
fig = figure(plot_width = 400, plot_height = 200)
fig.hbar(y = [2,4,6], height = 1, left = 0, right = [1,2,3], color = "Cyan")
#output_file('bar.html')
output_notebook()  #just for jupyter notebook
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1311">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="db691b93-4d7a-4a1c-ab66-2de304fdbe54" data-root-id="1274"></div>

# %%
fig = figure(plot_width = 200, plot_height = 400)
fig.vbar(x = [1,2,3], width = 0.5, bottom = 0, top = [2,4,6], color = "Cyan")
#output_file('bar.html')
output_notebook()  #just for jupyter notebook
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1720">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b68feea6-3b64-4b2d-94c4-17a54da42274" data-root-id="1683"></div>

# %% [markdown]
# **Patch plot**
# A plot which shades a region of space in a specific color to show a region or a group having similar properties is termed as a patch plot in Bokeh. Figure object has patch() and patches() methods for this purpose.
#
# patch()
# This method adds patch glyph to given figure. The method has the following arguments −
#
# 1-> x--	The x-coordinates for the points of the patch.
#
# 2->	y--	The y-coordinates for the points of the patch.

# %%
p = figure(plot_width = 300, plot_height = 300)
p.patch(x = [1, 3,2,4], y = [2,3,5,7], color = "green")
#output_file('patch.html')
output_notebook()  #just for jupyter notebook
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1938">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="ba8f8d6d-8eaf-4398-844d-bc11f111672f" data-root-id="1901"></div>

# %% [markdown]
# patches()
# This method is used to draw multiple polygonal patches. It needs following arguments −
#
# 1->xs--	The x-coordinates for all the patches, given as a “list of lists”.
#
# 2->ys--	The y-coordinates for all the patches, given as a “list of lists”.

# %%
xs = [[5,3,4], [2,4,3], [2,3,5,4]]
ys = [[6,4,2], [3,6,7], [2,4,7,8]]
fig = figure()
fig.patches(xs, ys, fill_color = ['red', 'blue', 'black'], line_color = 'white')
#output_file('patch_plot.html')
output_notebook()  #just for jupyter notebook
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2165">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e4f06fbe-74bc-44af-9e49-8c0f48d441ad" data-root-id="2128"></div>

# %%
fig = figure()
fig.scatter([1, 4, 3, 2, 5], [6, 5, 2, 4, 7], marker = "circle", size = 20, fill_color = "grey")
#output_file('scatter.html')
output_notebook()  #just for jupyter notebook
show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2401">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5d4439fd-b2ae-4c20-af17-a7145b3b6233" data-root-id="2364"></div>
